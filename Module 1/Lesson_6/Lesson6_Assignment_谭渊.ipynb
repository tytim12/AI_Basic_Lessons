# %% [markdown]
# 各位同学，大家好!  欢迎各位开始学习我们的人工智能课程。
# 这门课程假设大家不具备机器学习和人工智能的知识，但是希望大家具备初级的Python编程能力。
# 这门课程结束后，希望大家掌握Python语言以及人工智能基础知识，对CV，NLP，RS领域有一定深入的理解与编程能力。

# %% [markdown]
# # 本次作业要求

# %% [markdown]
# ## 作业形式

# %% [markdown]
# 复现课程代码
# 完成课后作业

# %% [markdown]
# ## 作业提交方式

# %% [markdown]
# 完成填写此`jupyter`文件，提交至自己的github，或通过KKB作业平台提交附件

# %% [markdown]
# ## 作业截止时间

# %% [markdown]
# 每次课程作业都会在下次课程(2019年11月15日)进行讲解，最好在一周内尽快提交。
# 此次作业批改截止时间：2019年11月22日

# %% [markdown]
# # 完成以下问答和编程练习

# %% [markdown]
# **理论部分**
# 无

# %% [markdown]
# **编程实践部分**

# %% [markdown]
# 1. 数据集保存及读取
# 添加编号列，并将数据集写入到`machine_learning.csv`文件，使用pandas读取验证文件是否有效(无错即可)。
# 添加一条记录，`青绿 硬挺 浊响 稍糊 平坦 硬滑 0.666 0.111 好`
# 再使用普通文件读取将数据集读取出来，列名读取到`columns`，数据(带编号)读取到`datalist`
# 在所有数据中过滤出色泽='浅白'的数据
# 在所有数据中过滤出密度大于0.5的数据

# %%
import pandas as pd

dataset = \
"""色泽 根蒂 敲声 纹理 脐部 触感 密度 含糖率 好瓜
青绿 蜷缩 浊响 清晰 凹陷 硬滑 0.697 0.460 是
乌黑 蜷缩 沉闷 清晰 凹陷 硬滑 0.774 0.376 是
乌黑 蜷缩 浊响 清晰 凹陷 硬滑 0.634 0.264 是
青绿 蜷缩 沉闷 清晰 凹陷 硬滑 0.608 0.318 是
浅白 蜷缩 浊响 清晰 凹陷 硬滑 0.556 0.215 是
青绿 稍蜷 浊响 清晰 稍凹 软粘 0.403 0.237 是
乌黑 稍蜷 浊响 稍糊 稍凹 软粘 0.481 0.149 是
乌黑 稍蜷 浊响 清晰 稍凹 硬滑 0.437 0.211 是
乌黑 稍蜷 沉闷 稍糊 稍凹 硬滑 0.666 0.091 否
青绿 硬挺 清脆 清晰 平坦 软粘 0.243 0.267 否
浅白 硬挺 清脆 模糊 平坦 硬滑 0.245 0.057 否
浅白 蜷缩 浊响 模糊 平坦 软粘 0.343 0.099 否
青绿 稍蜷 浊响 稍糊 凹陷 硬滑 0.639 0.161 否
浅白 稍蜷 沉闷 稍糊 凹陷 硬滑 0.657 0.198 否
乌黑 稍蜷 浊响 清晰 稍凹 软粘 0.360 0.370 否
浅白 蜷缩 浊响 模糊 平坦 硬滑 0.593 0.042 否
青绿 蜷缩 沉闷 稍糊 稍凹 硬滑 0.719 0.103 否"""

# write into a file
# your code here 
dataset = dataset.replace(' ', ',')
file = r'machine_learning.csv'
with open(file, 'w') as f:
    f.write(dataset)
print('File generated.')

# add a new data
# your code here
newData = "青绿 硬挺 浊响 稍糊 平坦 硬滑 0.666 0.111 好"
with open(file, 'a') as f:
    f.write('\n')
    f.write(newData.replace(' ', ','))
print('New line added.\n')

# vertify 
print("Use Pandas to verify if the file is created and new line is added properly.")
df = pd.read_csv(r'./machine_learning.csv', encoding = 'gbk')
print(df.head())


# read file
f = open(file, 'r').read().splitlines()

# your code here
columns = ['编号'] + f[0].split(',')
datalist = [[i] + line.split(',') for i, line in enumerate(f[1:])]

# vertify
print("\nverifying")
print(columns==['编号', '色泽', '根蒂', '敲声', '纹理', '脐部', '触感', '密度', '含糖率', '好瓜'])
print(datalist[-1]==['青绿', '硬挺', '浊响', '稍糊', '平坦', '硬滑', '0.666', '0.111', '好'])

# your code here
# 在所有数据中过滤出色泽='浅白'的数据
data1 = list(filter(lambda x: x[1] == '浅白', datalist))
print("\n色泽='浅白'的数据如下:")
print(columns)
for item in data1:
    print(item)
print()

# 在所有数据中过滤出密度大于0.5的数据
data2 = list(filter(lambda x: float(x[7]) > 0.5, datalist))
print("\n密度大于0.5的数据如下:")
print(columns)
for item in data2:
    print(item)
# Out:
# File generated.
# New line added.
#
# Use Pandas to verify if the file is created and new line is added properly.
#    色泽  根蒂  敲声  纹理  脐部  触感     密度    含糖率 好瓜
# 0  青绿  蜷缩  浊响  清晰  凹陷  硬滑  0.697  0.460  是
# 1  乌黑  蜷缩  沉闷  清晰  凹陷  硬滑  0.774  0.376  是
# 2  乌黑  蜷缩  浊响  清晰  凹陷  硬滑  0.634  0.264  是
# 3  青绿  蜷缩  沉闷  清晰  凹陷  硬滑  0.608  0.318  是
# 4  浅白  蜷缩  浊响  清晰  凹陷  硬滑  0.556  0.215  是
#
# verifying
# True
# False
#
# 色泽='浅白'的数据如下:
# ['编号', '色泽', '根蒂', '敲声', '纹理', '脐部', '触感', '密度', '含糖率', '好瓜']
# [4, '浅白', '蜷缩', '浊响', '清晰', '凹陷', '硬滑', '0.556', '0.215', '是']
# [10, '浅白', '硬挺', '清脆', '模糊', '平坦', '硬滑', '0.245', '0.057', '否']
# [11, '浅白', '蜷缩', '浊响', '模糊', '平坦', '软粘', '0.343', '0.099', '否']
# [13, '浅白', '稍蜷', '沉闷', '稍糊', '凹陷', '硬滑', '0.657', '0.198', '否']
# [15, '浅白', '蜷缩', '浊响', '模糊', '平坦', '硬滑', '0.593', '0.042', '否']
#
#
# 密度大于0.5的数据如下:
# ['编号', '色泽', '根蒂', '敲声', '纹理', '脐部', '触感', '密度', '含糖率', '好瓜']
# [0, '青绿', '蜷缩', '浊响', '清晰', '凹陷', '硬滑', '0.697', '0.460', '是']
# ...

# %% [markdown]
# ## Use Pandas to redo above

# %%
import pandas as pd
import numpy as np

dataset = \
"""色泽 根蒂 敲声 纹理 脐部 触感 密度 含糖率 好瓜
青绿 蜷缩 浊响 清晰 凹陷 硬滑 0.697 0.460 是
乌黑 蜷缩 沉闷 清晰 凹陷 硬滑 0.774 0.376 是
乌黑 蜷缩 浊响 清晰 凹陷 硬滑 0.634 0.264 是
青绿 蜷缩 沉闷 清晰 凹陷 硬滑 0.608 0.318 是
浅白 蜷缩 浊响 清晰 凹陷 硬滑 0.556 0.215 是
青绿 稍蜷 浊响 清晰 稍凹 软粘 0.403 0.237 是
乌黑 稍蜷 浊响 稍糊 稍凹 软粘 0.481 0.149 是
乌黑 稍蜷 浊响 清晰 稍凹 硬滑 0.437 0.211 是
乌黑 稍蜷 沉闷 稍糊 稍凹 硬滑 0.666 0.091 否
青绿 硬挺 清脆 清晰 平坦 软粘 0.243 0.267 否
浅白 硬挺 清脆 模糊 平坦 硬滑 0.245 0.057 否
浅白 蜷缩 浊响 模糊 平坦 软粘 0.343 0.099 否
青绿 稍蜷 浊响 稍糊 凹陷 硬滑 0.639 0.161 否
浅白 稍蜷 沉闷 稍糊 凹陷 硬滑 0.657 0.198 否
乌黑 稍蜷 浊响 清晰 稍凹 软粘 0.360 0.370 否
浅白 蜷缩 浊响 模糊 平坦 硬滑 0.593 0.042 否
青绿 蜷缩 沉闷 稍糊 稍凹 硬滑 0.719 0.103 否"""

# 转换 dataset，去掉换行符，区分 columns 和 数据内容
data = dataset.split('\n')
for i, item in enumerate(data):
    data[i] = item.split(' ')
columns = data[0]
datalist = data[1:]

# 把数据内容转换为 Series， 再创建数据框
ndlist = np.array(datalist)
data = pd.DataFrame(ndlist, columns = columns)

data.head()
# Out:
#    色泽  根蒂  敲声  纹理  脐部  触感     密度    含糖率 好瓜
# 0  青绿  蜷缩  浊响  清晰  凹陷  硬滑  0.697  0.460  是
# 1  乌黑  蜷缩  沉闷  清晰  凹陷  硬滑  0.774  0.376  是
# 2  乌黑  蜷缩  浊响  清晰  凹陷  硬滑  0.634  0.264  是
# 3  青绿  蜷缩  沉闷  清晰  凹陷  硬滑  0.608  0.318  是
# 4  浅白  蜷缩  浊响  清晰  凹陷  硬滑  0.556  0.215  是

# %%
# add new data
newData = "青绿 硬挺 浊响 稍糊 平坦 硬滑 0.666 0.111 好"
newData = newData.split(' ')
data.loc[data.shape[0]] = newData
data.tail()
# Out:
#     色泽  根蒂  敲声  纹理  脐部  触感     密度    含糖率 好瓜
# 13  浅白  稍蜷  沉闷  稍糊  凹陷  硬滑  0.657  0.198  否
# 14  乌黑  稍蜷  浊响  清晰  稍凹  软粘  0.360  0.370  否
# 15  浅白  蜷缩  浊响  模糊  平坦  硬滑  0.593  0.042  否
# 16  青绿  蜷缩  沉闷  稍糊  稍凹  硬滑  0.719  0.103  否
# 17  青绿  硬挺  浊响  稍糊  平坦  硬滑  0.666  0.111  好

# %%
# 色泽 = 浅白
data[data.色泽 == '浅白']
# Out:
#     色泽  根蒂  敲声  纹理  脐部  触感     密度    含糖率 好瓜
# 4   浅白  蜷缩  浊响  清晰  凹陷  硬滑  0.556  0.215  是
# 10  浅白  硬挺  清脆  模糊  平坦  硬滑  0.245  0.057  否
# 11  浅白  蜷缩  浊响  模糊  平坦  软粘  0.343  0.099  否
# 13  浅白  稍蜷  沉闷  稍糊  凹陷  硬滑  0.657  0.198  否
# 15  浅白  蜷缩  浊响  模糊  平坦  硬滑  0.593  0.042  否

# %%
# 密度 > 0.5
data['密度'] = data.密度.apply(float)
data[data.密度 > 0.5]
# Out:
#     色泽  根蒂  敲声  纹理  脐部  触感     密度    含糖率 好瓜
# 0   青绿  蜷缩  浊响  清晰  凹陷  硬滑  0.697  0.460  是
# 1   乌黑  蜷缩  沉闷  清晰  凹陷  硬滑  0.774  0.376  是
# 2   乌黑  蜷缩  浊响  清晰  凹陷  硬滑  0.634  0.264  是
# 3   青绿  蜷缩  沉闷  清晰  凹陷  硬滑  0.608  0.318  是
# 4   浅白  蜷缩  浊响  清晰  凹陷  硬滑  0.556  0.215  是
# 8   乌黑  稍蜷  沉闷  稍糊  稍凹  硬滑  0.666  0.091  否
# 12  青绿  稍蜷  浊响  稍糊  凹陷  硬滑  0.639  0.161  否
# 13  浅白  稍蜷  沉闷  稍糊  凹陷  硬滑  0.657  0.198  否
# 15  浅白  蜷缩  浊响  模糊  平坦  硬滑  0.593  0.042  否
# 16  青绿  蜷缩  沉闷  稍糊  稍凹  硬滑  0.719  0.103  否
# 17  青绿  硬挺  浊响  稍糊  平坦  硬滑  0.666  0.111  好
